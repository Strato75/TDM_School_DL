# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#function = lambda x: (x ** 3)-(3 *(x ** 2))+7
#function = lambda x: sinc(x)+ sinc(x-2)
function = lambda x: np.sin((x%13))/(x%13)

#Get 1000 evenly spaced numbers between -1 and 3 (arbitratil chosen to ensure steep curve)
x = np.linspace(.5,13,500)
#x = np.linspace(-1, 3,500)

#Plot the curve
f = figure(figsize(8,5))
plot(x, function(x), lw=3, label='${sin(x)/x}$')
ylabel('Value', fontsize=12)
xlabel('weight value', fontsize=12)
title('Loss Function', fontsize=16)
grid()
legend()
f.savefig("figures/Gradient_descent.png", dpi=300, transparency=True)
# Out:
# /home/giovanni/.virtualenvs/python3-stat-ML/lib/python3.7/site-packages/ipykernel_launcher.py:3: RuntimeWarning: invalid value encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
def deriv(x):
    
    '''
    Description: This function takes in a value of x and returns its derivative based on the 
    initial function we specified.
    
    Arguments:
    
    x - a numerical value of x 
    
    Returns:
    
    x_deriv - a numerical value of the derivative of x
    
    '''
    
    #x_deriv = 3* (x**2) - (6 * (x))
    
    x_deriv = (x*np.cos(x)-np.sin(x))/ (x**2) if x != 0 else 1
    return x_deriv

# %%
def step(x_new, x_prev, precision, l_r):
    
    '''
    Description: This function takes in an initial or previous value for x, updates it based on 
    steps taken via the learning rate and outputs the most minimum value of x that reaches the precision satisfaction.
    
    Arguments:
    
    x_new - a starting value of x that will get updated based on the learning rate
    
    x_prev - the previous value of x that is getting updated to the new one
    
    precision - a precision that determines the stop of the stepwise descent 
    
    l_r - the learning rate (size of each descent step)
    
    Output:
    
    1. Prints out the latest new value of x which equates to the minimum we are looking for
    2. Prints out the the number of x values which equates to the number of gradient descent steps
    3. Plots a first graph of the function with the gradient descent path
    4. Plots a second graph of the function with a zoomed in gradient descent path in the important area
    
    '''
    
    # create empty lists where the updated values of x and y wil be appended during each iteration
    
    x_list, y_list = [x_new], [function(x_new)]
    # keep looping until your desired precision
    while abs(x_new - x_prev) > precision:
        
        #d_x = -(function(x_new) - function(x_prev)) / (x_new - x_prev)
        # change the value of x
        x_prev = x_new
        
        # get the derivation of the old value of x and change sign
        d_x = - deriv(x_prev)
        #
        # get your new value of x by adding the previous, the multiplication of the derivative and the learning rate
        x_new = x_prev + (l_r * d_x)
        
        #print (x_prev, x_new, d_x)
        #print (x_new, x_prev, x_new - x_prev)
        
        # append the new value of x to a list of all x-s for later visualization of path
        x_list.append(x_new)
        
        # append the new value of y to a list of all y-s for later visualization of path
        y_list.append(function(x_new))
        
        
    print ("Local minimum occurs at: "+ str(x_new))
    print ("Number of steps: " + str(len(x_list)))
    
    
    return x_list,y_list

# %%
#Implement gradient descent (all the arguments are arbitrarily chosen)

#x_list, y_list = step(0.5, 0, 0.001, 0.05)
x_list, y_list = step(0.6, 0.5, 0.001, 1)

f=figure(figsize(16,5))

subplot(1,2,1)
scatter(x_list,y_list,c="g")
plot(x_list,y_list,c="g", lw=3)
plot(x,function(x), c="r", lw=2,alpha=0.6)
ylabel('Loss function', fontsize=12)
xlabel('weight value', fontsize=12)
#xlim(0.4,10)
title("Gradient descent", fontsize=16)
tight_layout()
grid()
#f.savefig("/home/giovanni/Scrivania/Immagini_Presentazione_TDM/Gradient_descent.png", dpi=300, transparency=True)


#figure(figsize(8,5))
subplot(1,2,2)
scatter(x_list,y_list,c="g")
plot(x,function(x), c="r", lw=3)
plot(x_list,y_list,c="g")
xlabel('weight value', fontsize=12)
#ylabel('Loss function', fontsize=12)
xlim([4.2,4.8])
ylim(-.225,-0.2)
title("Gradient descent: Zoom", fontsize=16)
tight_layout()
grid()
f.savefig("figures/Gradient_descent_zoom.png", dpi=300, transparency=True)
# Out:
# Local minimum occurs at: 4.490040907469482
# Number of steps: 32
# /home/giovanni/.virtualenvs/python3-stat-ML/lib/python3.7/site-packages/ipykernel_launcher.py:3: RuntimeWarning: invalid value encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/giovanni/.virtualenvs/python3-stat-ML/lib/python3.7/site-packages/ipykernel_launcher.py:3: RuntimeWarning: invalid value encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
#Implement gradient descent (all the arguments are arbitrarily chosen)

#x_list, y_list = step(0.5, 0, 0.001, 0.05)
x_list, y_list = step(0.6, 0.5, 0.001, 9)

f=figure(figsize(16,5))

subplot(1,2,1)
scatter(x_list,y_list,c="g")
plot(x_list,y_list,c="g", lw=3)
plot(x,function(x), c="r", lw=2,alpha=0.6)
ylabel('Loss function', fontsize=12)
xlabel('weight value', fontsize=12)
#xlim(0.4,10)
title("Gradient descent", fontsize=16)
tight_layout()
grid()
#savefig("/home/giovanni/Scrivania/Immagini_Presentazione_TDM/Gradient_descent_hlr.png", dpi=300, transparency=True)


#figure(figsize(8,5))
subplot(1,2,2)
scatter(x_list,y_list,c="g")
plot(x,function(x), c="r", lw=3)
plot(x_list,y_list,c="g")
xlabel('weight value', fontsize=12)
#ylabel('Loss function', fontsize=12)
xlim([4,5])
ylim(-.22,-0.2)
title("Gradient descent: Zoom", fontsize=16)
tight_layout()
grid()
f.savefig("figures/Gradient_descent_zoom_hlr.png", dpi=300, transparency=True)
# Out:
# Local minimum occurs at: 4.4929238868848556
# Number of steps: 133
# /home/giovanni/.virtualenvs/python3-stat-ML/lib/python3.7/site-packages/ipykernel_launcher.py:3: RuntimeWarning: invalid value encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/giovanni/.virtualenvs/python3-stat-ML/lib/python3.7/site-packages/ipykernel_launcher.py:3: RuntimeWarning: invalid value encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
#Implement gradient descent (all the arguments are arbitrarily chosen)

#x_list, y_list = step(0.5, 0, 0.001, 0.05)
x_list, y_list = step(9, 9.2, 0.001, 3)

f=figure(figsize(16,5))
subplot(1,2,1)
scatter(x_list,y_list,c="g")
plot(x_list,y_list,c="g", lw=3)
plot(x,function(x), c="r", lw=2,alpha=0.6)
ylabel('Loss function', fontsize=12)
xlabel('weight value', fontsize=12)
#xlim(0.4,10)
title("Gradient descent", fontsize=16)
tight_layout()
grid()
#savefig("/home/giovanni/Scrivania/Immagini_Presentazione_TDM/Gradient_descent_minloc.png", dpi=300, transparency=True)


#figure(figsize(8,5))
subplot(1,2,2)
scatter(x_list,y_list,c="g")
plot(x,function(x), c="r", lw=3)
plot(x_list,y_list,c="g")
xlabel('weight value', fontsize=12)
#ylabel('Loss function', fontsize=12)
xlim([8.8,12])
ylim(-0.2,0.1)
title("Gradient descent: Zoom", fontsize=16)
tight_layout()
grid()
f.savefig("figures/Gradient_descent_zoom_minloc.png", dpi=300, transparency=True)
# Out:
# Local minimum occurs at: 10.901923395489098
# Number of steps: 23
# /home/giovanni/.virtualenvs/python3-stat-ML/lib/python3.7/site-packages/ipykernel_launcher.py:3: RuntimeWarning: invalid value encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/giovanni/.virtualenvs/python3-stat-ML/lib/python3.7/site-packages/ipykernel_launcher.py:3: RuntimeWarning: invalid value encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
#Implement gradient descent (all the arguments are arbitrarily chosen)

#x_list, y_list = step(0.5, 0, 0.001, 0.05)
x_list, y_list = step(7, 6.8, 0.001, 3)

f=figure(figsize(16,5))
subplot(1,2,1)
scatter(x_list,y_list,c="g")
plot(x_list,y_list,c="g", lw=3)
plot(x,function(x), c="r", lw=2,alpha=0.6)
ylabel('Loss function', fontsize=12)
xlabel('weight value', fontsize=12)
#xlim(0.4,10)
title("Gradient descent", fontsize=16)
tight_layout()
grid()
#savefig("/home/giovanni/Scrivania/Immagini_Presentazione_TDM/Gradient_descent_minloc.png", dpi=300, transparency=True)


#figure(figsize(8,5))
subplot(1,2,2)
scatter(x_list,y_list,c="g")
plot(x,function(x), c="r", lw=3)
plot(x_list,y_list,c="g")
xlabel('weight value', fontsize=12)
#ylabel('Loss function', fontsize=12)
xlim([4.2,4.8])
ylim(-.225,-0.2)
title("Gradient descent: Zoom", fontsize=16)
tight_layout()
grid()
f.savefig("figures/Gradient_descent_zoom_reverse.png", dpi=300, transparency=True)
# Out:
# Local minimum occurs at: 4.49380102546653
# Number of steps: 13
# /home/giovanni/.virtualenvs/python3-stat-ML/lib/python3.7/site-packages/ipykernel_launcher.py:3: RuntimeWarning: invalid value encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/giovanni/.virtualenvs/python3-stat-ML/lib/python3.7/site-packages/ipykernel_launcher.py:3: RuntimeWarning: invalid value encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
#Implement gradient descent (all the arguments are arbitrarily chosen)

#x_list, y_list = step(0.5, 0, 0.001, 0.05)
x_list, y_list = step(0.6, 0.5, 0.01, 15.2)

f=figure(figsize(16,5))

subplot(1,2,1)
scatter(x_list,y_list,c="g")
plot(x_list,y_list,c="g", lw=3)
plot(x,function(x), c="r", lw=2,alpha=0.6)
ylabel('Loss function', fontsize=12)
xlabel('weight value', fontsize=12)
#xlim(0.4,10)
title("Gradient descent", fontsize=16)
tight_layout()
grid()
#savefig("/home/giovanni/Scrivania/Immagini_Presentazione_TDM/Gradient_descent_hlr.png", dpi=300, transparency=True)


#figure(figsize(8,5))
subplot(1,2,2)
scatter(x_list,y_list,c="g")
plot(x,function(x), c="r", lw=3)
plot(x_list,y_list,c="g")
xlabel('weight value', fontsize=12)
#ylabel('Loss function', fontsize=12)
xlim(10,12)
ylim(-0.2,0.1)
title("Gradient descent: Zoom", fontsize=16)
tight_layout()
grid()
f.savefig("figures/Gradient_descent_zoom_toohlr.png", dpi=300, transparency=True)
# Out:
# Local minimum occurs at: 10.902077582103287
# Number of steps: 15
# /home/giovanni/.virtualenvs/python3-stat-ML/lib/python3.7/site-packages/ipykernel_launcher.py:3: RuntimeWarning: invalid value encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/giovanni/.virtualenvs/python3-stat-ML/lib/python3.7/site-packages/ipykernel_launcher.py:3: RuntimeWarning: invalid value encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until
